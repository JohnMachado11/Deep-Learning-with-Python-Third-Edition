# %% [markdown]
# ## Data Representations for Neural Networks

# %% [markdown]
# ### Scalars (rank-0 tensors)

# %%
import numpy as np

x = np.array(12)
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %% [markdown]
# ### Vectors (rank-1 tensors)

# %%
x = np.array([12, 3, 6, 14, 7])
x
# Out:
# array([12,  3,  6, 14,  7])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# ### Matrices (rank-2 tensors)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36, 2]])
x
# Out:
# array([[ 5, 78,  2, 34,  0],
#        [ 6, 79,  3, 35,  1],
#        [ 7, 80,  4, 36,  2]])

# %%
x.ndim
# Out:
# 2

# %%
x.sum(axis=0) # sum across rows 
# 5 + 6 + 7 = 18
# Out:
# array([ 18, 237,   9, 105,   3])

# %%
x.sum(axis=1) # sum across columns
# 5 + 78 + 2 + 34 + 0 = 119
# Out:
# array([119, 124, 129])

# %% [markdown]
# #### Rank-3 tensors and higher-rank tensors

# %%
x = np.array([[[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]]])

# %%
x.ndim
# Out:
# 3

# %%
x.shape
# Out:
# (3, 3, 5)

# %% [markdown]
# <nop/> <div style="width: 800px;">![data_tensors.svg](attachment:image-2.png)</div>

# %% [markdown]
# #### Key attributes

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.ndim
# Out:
# 3

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# <nop/> <div style="width: 800px;">![rank_3_tensor.svg](attachment:image.png)</div>

# %%
import matplotlib.pyplot as plt

digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_labels[4]
# Out:
# np.uint8(9)

# %% [markdown]
# #### Manipulating tensors in NumPy

# %%
my_slice = train_images[10:100]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
# Equivalent to the previous example
my_slice = train_images[10:100, :, :]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
# Also equivalent to the previous example
my_slice = train_images[10:100, 0:28, 0:28]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
# To select 14 × 14 pixels in the bottom-right corner of all images, you would do this:
my_slice = train_images[:, 14:, 14:]

# %%
# my_slice[0]

# %%
# To crop the images to patches of 14 × 14 pixels centered in the middle, do this:
my_slice = train_images[:, 7:-7, 7:-7]

# %%
# my_slice[0]

# %% [markdown]
# #### The notion of data batches

# %% [markdown]
# <nop/> <div style="width: 800px;">![data_batches.svg](attachment:image.png)</div>

# %%
batch = train_images[:128]

# %%
batch.shape
# Out:
# (128, 28, 28)

# %%
# Next batch
batch = train_images[128:256]

# %%
batch.shape
# Out:
# (128, 28, 28)

# %%
# The nth batch
n = 3
batch = train_images[128 * n : 128 * (n + 1)]

# %%
print("First part of slice:", 128 * n)
print("Second part of slice:", 128 * (n + 1))
# Out:
# First part of slice: 384
# Second part of slice: 512

# %%
256 + 128
# Out:
# 384

# %%
batch.shape
# Out:
# (128, 28, 28)

# %% [markdown]
# <nop/> <div style="width: 800px;">![batch_tensor.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![vectors.svg](attachment:image.png)</div>
# <nop/> <div style="width: 800px;">![vectors_2.svg](attachment:image-2.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![images.svg](attachment:image.png)</div>
#
# <nop/> <div style="width: 350px;">![images_2.svg](attachment:image-2.png)</div>
#
# <nop/> <div style="width: 700px;">![image_3.svg](attachment:image-3.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![video.svg](attachment:image.png)</div>

# %% [markdown]
# ## Time Series Example

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series_example.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series_example_2.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series_example_3.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series_example_4.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series_example_5.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 700px;">![time_series_visual.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series_example_6.svg](attachment:image.png)</div>

# %% [markdown]
# <nop/> <div style="width: 800px;">![time_series_example_7.svg](attachment:image.png)</div>
